# %% [markdown]
# ## I, Khái quát dữ liệu

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./Loan_default.csv", index_col=False)
df.sample(10)
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 186707  BNJHL3SFNE   22   25819      230297          442              16
# 57266   JMDLQI4MYT   39   34056      184512          730              77
# 244382  RQAY0NU6C5   59  138734      169206          422              10
# 55494   ONB7TLFGUW   36  134878      122807          576              77
# 101454  XBF0R8M7P2   19  136959      238798          776              14
# 36421   B4SVU9RGM5   22  124744      187635          803              64
# 96698   5W5R5V4DB1   18   73785      201356          680              83
# 74412   VEO2EVOKTD   25   26885      147384          623              12
# 35824   8OME5JDP5D   22   73311      194451          376             110
# 90233   VBH0SXM6DD   54   25721      243458          716              31
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 186707               3         14.45        12      0.56          PhD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='object')

# %%
df.hist(figsize=(12,12), bins=30)
plt.suptitle("Histogram of Features", fontsize=16)
plt.show()

# %% [markdown]
# II, Phân tích và tìm kiếm các biến phù hợp

# %% [markdown]
# Các cột bị trên 50% giá trị null rất khó cho việc thay thế giá trị cũng như giá trị mang lại cũng không nhiều nên quyết định sẽ là loại bỏ

# %%
def drop_columns_with_nulls(df, threshold=0.5):
    row_count = len(df)
    null_threshold = threshold * row_count
    cols_to_drop = [col for col in df.columns if df[col].isnull().sum() > null_threshold]

    return df.drop(columns=cols_to_drop)

# %%
df = drop_columns_with_nulls(df)

# %%
df.dtypes
# Out:
# LoanID             object
# Age                 int64
# Income              int64
# LoanAmount          int64
# CreditScore         int64
# MonthsEmployed      int64
# NumCreditLines      int64
# InterestRate      float64
# LoanTerm            int64
# DTIRatio          float64
# Education          object
# EmploymentType     object
# MaritalStatus      object
# HasMortgage        object
# HasDependents      object
# LoanPurpose        object
# HasCoSigner        object
# Default             int64
# dtype: object

# %% [markdown]
# ## II, Phân tích PCA với các côt số

# %%
from sklearn.decomposition import PCA
import numpy as np
numeric_df = df.select_dtypes(include=['number'])
cleaned_df = numeric_df.dropna(axis=0)

pcs = PCA()
pcs.fit(cleaned_df)
# Out:
# PCA()

# %%
summ = {'Standard deviation': np.sqrt(pcs.explained_variance_), 'Proportion of variance': pcs.explained_variance_ratio_,
'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)}
pcsSummary_df = pd.DataFrame(summ)
pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df.round(4)
# Out:
#                                PC1         PC2       PC3      PC4      PC5  \
# Standard deviation      70840.7176  38962.9928  158.9036  34.6431  16.9692
# Proportion of variance      0.7677      0.2323    0.0000   0.0000   0.0000
# Cumulative proportion       0.7677      1.0000    1.0000   1.0000   1.0000
#
#                             PC6     PC7     PC8     PC9    PC10
# Standard deviation      14.9903  6.6365  1.1171  0.3083  0.2308
# Proportion of variance   0.0000  0.0000  0.0000  0.0000  0.0000
# Cumulative proportion    1.0000  1.0000  1.0000  1.0000  1.0000

# %%
kaiser_criteria = pcsSummary_df.loc['Standard deviation'] > 1
selected_pcs = pcsSummary_df.loc[:, kaiser_criteria]
selected_pcs
# Out:
#                                  PC1           PC2         PC3           PC4  \
# Standard deviation      70840.717645  38962.992816  158.903581  3.464313e+01
# Proportion of variance      0.767746      0.232250    0.000004  1.836055e-07
# Cumulative proportion       0.767746      0.999996    1.000000  9.999999e-01
#
#                                  PC5           PC6           PC7           PC8
# Standard deviation      1.696924e+01  1.499030e+01  6.636532e+00  1.117053e+00
# Proportion of variance  4.405310e-08  3.437734e-08  6.738044e-09  1.908969e-10
# Cumulative proportion   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), columns=pcsSummary_df.columns, #Note the use of the
index=cleaned_df.columns)
pcsComponents_df.loc[:, kaiser_criteria]
# Out:
#                          PC1           PC2           PC3       PC4  \
# Age            -4.681284e-07 -4.796979e-07 -5.207879e-05 -0.000176
# Income         -6.823556e-04  9.999998e-01  5.829125e-06 -0.000002
# LoanAmount      9.999998e-01  6.823556e-04 -2.826673e-06 -0.000001
# CreditScore     2.830390e-06 -5.827551e-06  1.000000e+00 -0.000140
# MonthsEmployed  1.377032e-06  2.381438e-06  1.403357e-04  0.999999
# NumCreditLines  1.253812e-08 -5.777957e-08  8.572894e-08  0.000041
# InterestRate   -2.145537e-07 -3.928194e-07  1.822986e-05  0.000021
# LoanTerm        6.080391e-07 -4.333677e-07  1.216010e-04 -0.000755
# DTIRatio        3.658457e-09  1.226142e-09 -1.511711e-06  0.000012
# Default         3.920868e-07 -8.141416e-07 -6.939637e-05 -0.000900
#
#                          PC5           PC6           PC7           PC8
# Age             1.076431e-03  9.999928e-01  6.534273e-04  9.810426e-05
# Income          4.319524e-07  4.756282e-07  3.978927e-07  6.501773e-08
# ...

# %%
PC_values = np.arange(pcs.n_components_) + 1
plt.plot(PC_values, pcs.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %% [markdown]
# ## III, Tiền sử lý dữu liệu

# %%
df_missing = ((df.isnull().sum()/len(df))*100)[((df.isnull().sum()/len(df))*100) > 0]
df_missing
# Out:
# Series([], dtype: float64)

# %%
def if_null_values(feat_name):
    if feat_name in df_missing:
        print((f"% of missing values = {df_missing[feat_name].round(2)}"))
    else:
        print(("No missing values"))

# %% [markdown]
# 1, LoanID | Mã định danh duy nhất cho mỗi khoản vay.

# %% [markdown]
# Dữ liệu này là không cần thiết cho việc dự đoán của mô hình nên sẽ loại bỏ

# %%
df.drop("LoanID", axis=1, inplace=True)
df.head(10)
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
# 5   25   90298       90448          720              18               2
# 6   38  111188      177025          429              80               1
# 7   56  126802      155511          531              67               4
# 8   36   42053       92357          827              83               1
# 9   40  132784      228510          480             114               4
#
#    InterestRate  LoanTerm  DTIRatio    Education EmploymentType MaritalStatus  \
# 0         15.23        36      0.44   Bachelor's      Full-time      Divorced
# ...

# %% [markdown]
# 2 Age | Tuổi của người vay.

# %%
if_null_values("Age")
# Out:
# No missing values

# %%
df['Age'].describe()
# Out:
# count    255347.000000
# mean         43.498306
# std          14.990258
# min          18.000000
# 25%          31.000000
# 50%          43.000000
# 75%          56.000000
# max          69.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(data=df, x='Age', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['Age'].describe()
# Out:
#             count       mean        std   min   25%   50%   75%   max
# Default
# 0        225694.0  44.409962  14.889574  18.0  32.0  45.0  57.0  69.0
# 1         29653.0  36.559539  13.897468  18.0  25.0  34.0  47.0  69.0

# %% [markdown]
# Đô tuổi trung bình của người vay trả được nợ là 44 và người không trả được nợ là 36, cách nhau 8 tuổi.

# %% [markdown]
# 3, Icome | Thu nhập hàng năm của người vay.

# %%
if_null_values("Income")
# Out:
# No missing values

# %%
df['Income'].describe()
# Out:
# count    255347.000000
# mean      82499.304597
# std       38963.013729
# min       15000.000000
# 25%       48825.500000
# 50%       82466.000000
# 75%      116219.000000
# max      149999.000000
# Name: Income, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['Income'], kde=True)
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.displot(data=df, x='Income', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['Income'].describe()
# Out:
#             count          mean           std      min      25%      50%  \
# Default
# 0        225694.0  83899.165995  38498.801232  15000.0  50994.0  84237.5
# 1         29653.0  71844.722659  40785.099507  15004.0  34022.0  66566.0
#
#                75%       max
# Default
# 0        117186.75  149999.0
# 1        106895.00  149995.0

# %% [markdown]
# Thu nhập của những người trả được nợ thường cao hơn người không trả được nợ, đặc biệt ở trung vị và Q1 giá trị trênh nhau rất lớn.

# %% [markdown]
# 4, LoanAmount | Số tiền được vay.

# %%
if_null_values("LoanAmount")
# Out:
# No missing values

# %%
df['LoanAmount'].describe()
# Out:
# count    255347.000000
# mean     127578.865512
# std       70840.706142
# min        5000.000000
# 25%       66156.000000
# 50%      127556.000000
# 75%      188985.000000
# max      249999.000000
# Name: LoanAmount, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['LoanAmount'], kde=True)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Count'>

# %%
sns.displot(data=df, x='LoanAmount', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
col = ['Income', 'LoanAmount']

for i in col:
    plt.figure(figsize=(8, 6))
    sns.boxplot(y=df[i])
    plt.title(f'BOX PLOT FOR {i}')
    plt.show()

# %% [markdown]
# Khoản vay có độ bao phủ lớn hơn thu nhập, trung bình vào khoảng 60000

# %%
df.groupby('Default')['LoanAmount'].describe()
# Out:
#             count           mean           std     min       25%       50%  \
# Default
# 0        225694.0  125353.656017  70708.101479  5001.0  63889.25  124236.0
# 1         29653.0  144515.311469  69547.822943  5000.0  88085.00  152672.0
#
#                75%       max
# Default
# 0        186177.75  249999.0
# 1        205468.00  249993.0

# %% [markdown]
# Nhóm vợ nợ thường là các khoản vay cao hơn nhóm trả được nợ, trung bình khoảng 20000

# %% [markdown]
# 5, CreditScore | Điểm tín dụng của người vay, thể hiện khả năng tín dụng.

# %%
if_null_values("CreditScore")
# Out:
# No missing values

# %%
df['CreditScore'].describe()
# Out:
# count    255347.000000
# mean        574.264346
# std         158.903867
# min         300.000000
# 25%         437.000000
# 50%         574.000000
# 75%         712.000000
# max         849.000000
# Name: CreditScore, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['CreditScore'], kde=True)
# Out:
# <Axes: xlabel='CreditScore', ylabel='Count'>

# %%
sns.displot(data=df, x='CreditScore', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['CreditScore'].describe()
# Out:
#             count        mean         std    min    25%    50%    75%    max
# Default
# 0        225694.0  576.232270  158.849404  300.0  439.0  577.0  714.0  849.0
# 1         29653.0  559.286143  158.521855  300.0  421.0  553.0  693.0  849.0

# %% [markdown]
# Nhóm những người trả được nợ thường có điểm tin dụng cao hơn nhóm không trả được nợ

# %% [markdown]
# 6, MonthsEmployed | Số tháng người vay đã làm việc.

# %%
if_null_values("MonthsEmployed")
# Out:
# No missing values

# %%
df['MonthsEmployed'].describe()
# Out:
# count    255347.000000
# mean         59.541976
# std          34.643376
# min           0.000000
# 25%          30.000000
# 50%          60.000000
# 75%          90.000000
# max         119.000000
# Name: MonthsEmployed, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['MonthsEmployed'], kde=True)
# Out:
# <Axes: xlabel='MonthsEmployed', ylabel='Count'>

# %%
sns.displot(data=df, x='MonthsEmployed', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['MonthsEmployed'].describe()
# Out:
#             count       mean        std  min   25%   50%   75%    max
# Default
# 0        225694.0  60.764721  34.556394  0.0  31.0  61.0  91.0  119.0
# 1         29653.0  50.235457  33.882499  0.0  21.0  46.0  78.0  119.0

# %% [markdown]
# 7, NumCreditLines | Số lượng dòng tín dụng (số thẻ tín dụng hoặc khoản vay mà người vay đang có).

# %%
if_null_values("NumCreditLines")
# Out:
# No missing values

# %%
df['NumCreditLines'].describe()
# Out:
# count    255347.000000
# mean          2.501036
# std           1.117018
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max           4.000000
# Name: NumCreditLines, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['NumCreditLines'], kde=True)
# Out:
# <Axes: xlabel='NumCreditLines', ylabel='Count'>

# %%
sns.displot(data=df, x='NumCreditLines', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['NumCreditLines'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%  max
# Default
# 0        225694.0  2.489566  1.116350  1.0  1.0  2.0  3.0  4.0
# 1         29653.0  2.588338  1.118258  1.0  2.0  3.0  4.0  4.0

# %% [markdown]
# Chỉ số về cả 2 nhóm không có nhiều khác biệt có thể xóa bỏ

# %% [markdown]
# 8, InterestRate | Lãi suất của khoản vay.

# %%
if_null_values("InterestRate")
# Out:
# No missing values

# %%
df['InterestRate'].describe()
# Out:
# count    255347.000000
# mean         13.492773
# std           6.636443
# min           2.000000
# 25%           7.770000
# 50%          13.460000
# 75%          19.250000
# max          25.000000
# Name: InterestRate, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['InterestRate'], kde=True)
# Out:
# <Axes: xlabel='InterestRate', ylabel='Count'>

# %%
sns.displot(data=df, x='InterestRate', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['InterestRate'].describe()
# Out:
#             count       mean       std  min    25%    50%    75%   max
# Default
# 0        225694.0  13.176994  6.612265  2.0   7.45  12.99  18.85  25.0
# 1         29653.0  15.896227  6.320304  2.0  11.06  16.93  21.36  25.0

# %% [markdown]
# nhóm người không trả được nợ thường có những khoản vay có lãi suất cao hơn nhóm trả được nợ.

# %% [markdown]
# 9, LoanTerm | Thời hạn của khoản vay tính theo tháng.

# %%
if_null_values("LoanTerm")
# Out:
# No missing values

# %%
df['LoanTerm'].describe()
# Out:
# count    255347.000000
# mean         36.025894
# std          16.969330
# min          12.000000
# 25%          24.000000
# 50%          36.000000
# 75%          48.000000
# max          60.000000
# Name: LoanTerm, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['LoanTerm'], kde=True)
# Out:
# <Axes: xlabel='LoanTerm', ylabel='Count'>

# %%
sns.displot(data=df, x='LoanTerm', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['LoanTerm'].describe()
# Out:
#             count       mean        std   min   25%   50%   75%   max
# Default
# 0        225694.0  36.022544  16.966374  12.0  24.0  36.0  48.0  60.0
# 1         29653.0  36.051394  16.992077  12.0  24.0  36.0  48.0  60.0

# %% [markdown]
# không có nhiều sự khác biệt ở cột thời hạn khoản vay, có thể loại bỏ

# %% [markdown]
# 10, DTIRatio | Tỷ lệ nợ trên thu nhập, thể hiện số nợ so với thu nhập.

# %%
if_null_values("DTIRatio")
# Out:
# No missing values

# %%
df['DTIRatio'].describe()
# Out:
# count    255347.000000
# mean          0.500212
# std           0.230917
# min           0.100000
# 25%           0.300000
# 50%           0.500000
# 75%           0.700000
# max           0.900000
# Name: DTIRatio, dtype: float64

# %%
plt.figure(figsize=(12,5), dpi=130)
sns.histplot(x=df['DTIRatio'], kde=True)
# Out:
# <Axes: xlabel='DTIRatio', ylabel='Count'>

# %%
sns.displot(data=df, x='DTIRatio', hue='Default', bins=100, height=4, aspect=3, kde=True);

# %%
df.groupby('Default')['DTIRatio'].describe()
# Out:
#             count      mean       std  min   25%   50%   75%  max
# Default
# 0        225694.0  0.498602  0.231099  0.1  0.30  0.50  0.70  0.9
# 1         29653.0  0.512467  0.229160  0.1  0.32  0.52  0.71  0.9

# %% [markdown]
# Nhóm không trả được nợ thường có tỉ lệ nợ trên thu nhập cao hơn nhóm trả được nợ

# %% [markdown]
# 11, Education | Trình độ học vấn cao nhất của người vay (Tiến sĩ, Thạc sĩ, Cử nhân, Trung học).

# %%
if_null_values("Education")
# Out:
# No missing values

# %%
df['Education'].value_counts()
# Out:
# Education
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='Education',data=df,hue='Default')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
charged_off = df[df['Default']==1].groupby("Education").count()['Default']
fully_paid = df[df['Default']==0].groupby("Education").count()['Default']
percentage_charged_off = (charged_off * 100)/(charged_off + fully_paid)
sns.barplot(percentage_charged_off);

# %% [markdown]
# Vì các giá trên có trọng số ngang nhau nên sẽ sử dụng onehot encoding để tránh gây nhầm lẫn cho mô hình.

# %%
tmp_col = pd.get_dummies(df['Education'], drop_first=False)
df = pd.concat([df.drop('Education', axis=1), tmp_col], axis=1)

# %%
df.shape
# Out:
# (255347, 20)

# %% [markdown]
# 12, EmploymentType | Loại hình việc làm của người vay (Toàn thời gian, Bán thời gian, Tự làm chủ, Thất nghiệp).

# %%
if_null_values("EmploymentType")
# Out:
# No missing values

# %%
df['EmploymentType'].value_counts()
# Out:
# EmploymentType
# Part-time        64161
# Unemployed       63824
# Self-employed    63706
# Full-time        63656
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='EmploymentType',data=df,hue='Default')
# Out:
# <Axes: xlabel='EmploymentType', ylabel='count'>

# %%
charged_off = df[df['Default']==1].groupby("EmploymentType").count()['Default']
fully_paid = df[df['Default']==0].groupby("EmploymentType").count()['Default']
percentage_charged_off = (charged_off * 100)/(charged_off + fully_paid)
sns.barplot(percentage_charged_off);

# %% [markdown]
# Có sự phân hóa rõ ràng giữa các nhóm nghề nghiệp theo phần trăm không trả được nợ. Nhóm thất nghiệp thường có tỉ lệ không trả được nợ cao nhất

# %% [markdown]
# Vì các giá trên có trọng số ngang nhau nên sẽ sử dụng onehot encoding để tránh gây nhầm lẫn cho mô hình.

# %%
tmp_col = pd.get_dummies(df['EmploymentType'], drop_first=False)
df = pd.concat([df.drop('EmploymentType', axis=1), tmp_col], axis=1)

# %%
df.shape
# Out:
# (255347, 23)

# %% [markdown]
# 13, MaritalStatus | Tình trạng hôn nhân của người vay (Độc thân, Đã kết hôn, Ly hôn).

# %%
if_null_values("MaritalStatus")
# Out:
# No missing values

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     85302
# Divorced    85033
# Single      85012
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='MaritalStatus',data=df,hue='Default')
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
charged_off = df[df['Default']==1].groupby("MaritalStatus").count()['Default']
fully_paid = df[df['Default']==0].groupby("MaritalStatus").count()['Default']
percentage_charged_off = (charged_off * 100)/(charged_off + fully_paid)
sns.barplot(percentage_charged_off);

# %% [markdown]
# Nhóm người đã kết hôn có tỉ lệ không trả được nợ thấp hơn các nhóm còn lại

# %% [markdown]
# Vì các giá trên có trọng số ngang nhau nên sẽ sử dụng onehot encoding để tránh gây nhầm lẫn cho mô hình.

# %%
tmp_col = pd.get_dummies(df['MaritalStatus'], drop_first=False)
df = pd.concat([df.drop('MaritalStatus', axis=1), tmp_col], axis=1)

# %%
df.shape
# Out:
# (255347, 25)

# %% [markdown]
# 14, HasMortgage | Người vay có thế chấp hay không (Có hoặc Không).

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
if_null_values("HasMortgage")
# Out:
# No missing values

# %%
df['HasMortgage'].value_counts()
# Out:
# HasMortgage
# Yes    127677
# No     127670
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='HasMortgage',data=df,hue='Default')
# Out:
# <Axes: xlabel='HasMortgage', ylabel='count'>

# %%
charged_off = df[df['Default']==1].groupby("HasMortgage").count()['Default']
fully_paid = df[df['Default']==0].groupby("HasMortgage").count()['Default']
percentage_charged_off = (charged_off * 100)/(charged_off + fully_paid)
sns.barplot(percentage_charged_off);

# %% [markdown]
# Không có nhiều sự phân hóa, nhóm có tài sản thế chấp có tỉ lệ không trả được nợ thấp hơn một chút

# %% [markdown]
# Cột có giá trị trọng số khác nhau nên sẽ sử dụng label encoding

# %%
df['HasMortgage'] = le.fit_transform(df['HasMortgage'])

# %%
df.shape
# Out:
# (255347, 25)

# %% [markdown]
# 15, HasDependents | Người vay có người phụ thuộc hay không (Có hoặc Không).

# %%
if_null_values("HasDependents")
# Out:
# No missing values

# %%
df['HasDependents'].value_counts()
# Out:
# HasDependents
# Yes    127742
# No     127605
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='HasDependents',data=df,hue='Default')
# Out:
# <Axes: xlabel='HasDependents', ylabel='count'>

# %%
charged_off = df[df['Default']==1].groupby("HasDependents").count()['Default']
fully_paid = df[df['Default']==0].groupby("HasDependents").count()['Default']
percentage_charged_off = (charged_off * 100)/(charged_off + fully_paid)
sns.barplot(percentage_charged_off);

# %% [markdown]
# Không có nhiều sự phân hóa, nhóm có người phụ thuộc có tỉ lệ không trả được nợ thấp hơn một chút

# %% [markdown]
# Cột có giá trị trọng số khác nhau nên sẽ sử dụng label encoding

# %%
df['HasDependents'] = le.fit_transform(df['HasDependents'])

# %%
df.shape
# Out:
# (255347, 25)

# %% [markdown]
# 16, LoanPurpose | Mục đích khoản vay (Nhà, Ô tô, Giáo dục, Kinh doanh, Khác).

# %%
if_null_values("LoanPurpose")
# Out:
# No missing values

# %%
df['LoanPurpose'].value_counts()
# Out:
# LoanPurpose
# Business     51298
# Home         51286
# Education    51005
# Other        50914
# Auto         50844
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='LoanPurpose',data=df,hue='Default')
# Out:
# <Axes: xlabel='LoanPurpose', ylabel='count'>

# %%
charged_off = df[df['Default']==1].groupby("LoanPurpose").count()['Default']
fully_paid = df[df['Default']==0].groupby("LoanPurpose").count()['Default']
percentage_charged_off = (charged_off * 100)/(charged_off + fully_paid)
sns.barplot(percentage_charged_off);

# %% [markdown]
# Vì các giá trên có trọng số ngang nhau nên sẽ sử dụng onehot encoding để tránh gây nhầm lẫn cho mô hình.

# %%
tmp_col = pd.get_dummies(df['LoanPurpose'], drop_first=False)
df = pd.concat([df.drop('LoanPurpose', axis=1), tmp_col], axis=1)

# %%
df.shape
# Out:
# (255347, 29)

# %% [markdown]
# 17, HasCoSigner | Khoản vay có người đồng ký tên hay không (Có hoặc Không).

# %%
if_null_values("HasCoSigner")
# Out:
# No missing values

# %%
df['HasCoSigner'].value_counts()
# Out:
# HasCoSigner
# Yes    127701
# No     127646
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='HasCoSigner',data=df,hue='Default')
# Out:
# <Axes: xlabel='HasCoSigner', ylabel='count'>

# %%
charged_off = df[df['Default']==1].groupby("HasCoSigner").count()['Default']
fully_paid = df[df['Default']==0].groupby("HasCoSigner").count()['Default']
percentage_charged_off = (charged_off * 100)/(charged_off + fully_paid)
sns.barplot(percentage_charged_off);

# %% [markdown]
# Không có nhiều sự phân hóa, nhóm có người đại diện ký thay có tỉ lệ không trả được nợ thấp hơn một chút

# %% [markdown]
# Cột có giá trị trọng số khác nhau nên sẽ sử dụng label encoding

# %%
df['HasCoSigner'] = le.fit_transform(df['HasCoSigner'])

# %%
df.shape
# Out:
# (255347, 29)

# %% [markdown]
# ## IV, Create Models

# %%
# !pip install xgboost
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
X = df.drop('Default', axis=1)
y = df['Default']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.dtypes.value_counts()
# Out:
# bool       16
# int64      10
# float64     2
# Name: count, dtype: int64

# %% [markdown]
# ### *** Trước khi sampling

# %% [markdown]
# ### 1, Ramdom Forest

# %%
rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=42)

# %%
preds = rf.predict(X_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     67681
#            1       0.70      0.03      0.06      8924
#
#     accuracy                           0.89     76605
#    macro avg       0.79      0.52      0.50     76605
# weighted avg       0.86      0.89      0.84     76605

# %%
cm = confusion_matrix(y_test, preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=rf.classes_, yticklabels=rf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### 2, Xg boost

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
preds = model.predict(X_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     67681
#            1       0.55      0.09      0.15      8924
#
#     accuracy                           0.89     76605
#    macro avg       0.72      0.54      0.54     76605
# weighted avg       0.85      0.89      0.85     76605

# %%
cm = confusion_matrix(y_test, preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=rf.classes_, yticklabels=rf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### *** Sau khi undersimpling

# %%
# !pip install imbalanced-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=42)
X_train_resample, y_train_resample=sm.fit_resample(X_train, y_train)
# Out:
# c:\Users\doduy\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\doduy\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\doduy\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\doduy\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
# ...

# %% [markdown]
# ### 1, Random Forests

# %%
rf_re = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=42)
rf_re.fit(X_train_resample, y_train_resample)
# Out:
# RandomForestClassifier(oob_score=True, random_state=42)

# %%
preds = rf_re.predict(X_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     67681
#            1       0.52      0.05      0.09      8924
#
#     accuracy                           0.88     76605
#    macro avg       0.70      0.52      0.52     76605
# weighted avg       0.84      0.88      0.84     76605

# %%
cm = confusion_matrix(y_test, preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=rf.classes_, yticklabels=rf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### 2, Xg boost

# %%
model_new = XGBClassifier()
model_new.fit(X_train_resample, y_train_resample)
model_new.save_model('xgb_model.json')

# %%
preds = model_new.predict(X_test)

# %%
cm = confusion_matrix(y_test, preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=rf.classes_, yticklabels=rf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     67681
#            1       0.55      0.08      0.14      8924
#
#     accuracy                           0.89     76605
#    macro avg       0.72      0.54      0.54     76605
# weighted avg       0.85      0.89      0.85     76605

# %% [markdown]
# ## V. Lưu mô hình

# %%
import joblib
joblib.dump(rf_re, "random_forest_model.joblib", compress=3)
# Out:
# ['random_forest_model.joblib']

# %%
model_new.save_model('xgb_model.json')
